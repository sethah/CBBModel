# %%
import pandas as pd
import numpy as np
import psycopg2
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
# %matplotlib inline

# %%
conn = psycopg2.connect(database="sethhendrickson", user="sethhendrickson", password="abc123",
                        host="localhost", port="5432")
cur = conn.cursor()

# %%
df = pd.read_sql("""SELECT * FROM kp_detailed""", conn)
teams = pd.read_sql("""SELECT * FROM teams""", conn)
teams = teams[['team_id', 'team_name', 'conf']]

# %%
df = df[df.neutral == 0]

# %%
df['home_margin'] = df.apply(lambda x: x.score1 - x.score2 if x.team1_id==x.hteam else x.score2-x.score1, axis=1)
df['predicted_home_margin'] = df.apply(lambda x: x.predicted_score - x.predicted_score2 if x.team1_id==x.hteam else x.predicted_score2-x.predicted_score, axis=1)

# %%
df['hmargin_diff'] = df.home_margin - df.predicted_home_margin
df = df[df.predicted_home_margin.abs() < 15]

# %%
gb = df.groupby('hteam').mean()
gb2 = df.groupby('hteam').count()

# %%
gb.sort('hmargin_diff', ascending=False).head()
# Out:
#           score1     score2  predicted_score  predicted_score2     team1_id  \
# hteam
# 1355   78.300000  63.425000        75.500000         67.875000  1350.050000
# 1438   64.529412  49.862745        63.568627         56.294118  1400.156863
# 1211   77.781250  63.218750        76.250000         66.718750  1223.500000
# 1176   70.459016  58.311475        65.245902         58.819672  1204.983607
# 1172   78.555556  65.250000        75.805556         67.611111  1206.305556
#
#           team2_id        ateam  neutral  home_margin  predicted_home_margin  \
# hteam
# 1355   1300.700000  1295.750000        0    11.825000               5.875000
# 1438   1322.647059  1284.803922        0    10.352941               4.490196
# 1211   1297.718750  1310.218750        0    12.687500               6.906250
# 1176   1265.983607  1294.967213        0     8.245902               3.081967
# 1172   1238.944444  1273.250000        0     8.805556               3.861111
#
#        hmargin_diff
# hteam
# 1355       5.950000
# 1438       5.862745
# 1211       5.781250
# 1176       5.163934
# 1172       4.944444

# %%
margin = pd.DataFrame({'team': gb.index.values, 'avg_margin_diff': gb.hmargin_diff.values, 'avg_margin':gb.home_margin.values})
gp = pd.DataFrame({'team': gb2.index.values, 'gp': gb2.score1.values})

# %%
margin = pd.merge(margin, teams, left_on='team', right_on='team_id')
margin = pd.merge(margin, gp, left_on='team', right_on='team')

# %%
major_conf = ['B10', 'ACC', 'BE', 'P12', 'SEC']
major_conf=['B10']
new = margin[margin.conf.isin(major_conf)].sort('avg_margin_diff', ascending=False)
# new.to_csv('B10.csv')
margin.sort('avg_margin_diff', ascending=False).head(100)
# Out:
#      avg_margin  avg_margin_diff  team  team_id      team_name  conf  gp
# 239   11.825000         5.950000  1355     1355    S Dakota St   Sum  40
# 319   10.352941         5.862745  1438     1438       Virginia   ACC  51
# 101   12.687500         5.781250  1211     1211        Gonzaga   WCC  32
# 67     8.245902         5.163934  1176     1176         Denver   Sum  61
# 63     8.805556         4.944444  1172     1172       Davidson   A10  36
# 131   12.923077         4.512821  1242     1242         Kansas   B12  39
# 214    5.775510         2.163265  1329     1329    Oklahoma St   B12  49
# 228    5.532258         2.161290  1344     1344     Providence    BE  62
# 236    7.129032         2.112903  1352     1352  Robert Morris   NEC  62
# 280    5.500000         2.106061  1397     1397      Tennessee   SEC  66
# 329    3.614035         2.105263  1450     1450  Washington St   P12  57
# 162    6.913793         2.086207  1273     1273         Mercer    SC  58
# 122    8.974359         2.076923  1233     1233           Iona  MAAC  39
# 146    5.604651         2.046512  1257     1257     Louisville   ACC  43
# 136    4.523077         2.046154  1247     1247       La Salle   A10  65
#
# [100 rows x 7 columns]

# %%
df[df.hteam==1355][['dt','home_margin','predicted_home_margin', 'hmargin_diff', 'venue', 'team1', 'team2', 'wloc']].sort('dt')
# Out:
#                dt  home_margin  predicted_home_margin  hmargin_diff  \
# 3731   2010-11-27           26                      9            17
# 22399  2010-11-30           17                     10             7
# 67     2010-12-04           -7                     -7             0
# 202    2010-12-11          -12                     -9            -3
# 3906   2011-01-08           -8                     -7            -1
# 11378  2011-01-20           -9                     -3            -6
# 601    2011-01-22           35                      8            27
# 19638  2011-02-10           11                      5             6
# 19880  2011-11-12            6                      3             3
# 20080  2011-12-30           12                     13            -1
# 11795  2012-02-02           15                      5            10
# 15318  2012-02-15           23                     10            13
# 12003  2012-02-18           21                      6            15
# 4752   2012-02-23           17                     14             3
# 23413  2012-11-13            7                     13            -6
# 15574  2012-12-09            6                     11            -5
# 15636  2013-01-10            7                      7             0
# 12724  2013-01-12           26                     11            15
# 2074   2013-01-26           16                      4            12
# 5668   2013-02-16            9                      5             4
# 24081  2013-11-14           -8                     -3            -5
# 18463  2013-11-25           12                     14            -2
# 18489  2013-11-26           13                      1            12
# 21054  2013-12-14           13                      7             6
# 9951   2014-01-16            9                      7             2
# 6428   2014-01-18           -9                     -2            -7
# 21531  2014-01-25           -8                     -4            -4
# 2604   2014-02-06           28                      3            25
# 21821  2014-02-27            9                      4             5
# 24573  2014-03-01           14                     10             4
# 16524  2014-11-21            2                     12           -10
# 16574  2014-12-06           20                      5            15
# 2983   2014-12-13            2                      9            -7
# 10517  2015-01-07           31                     10            21
# 10582  2015-01-14           15                     10             5
# 7523   2015-01-17           14                      8             6
# 22103  2015-01-21           29                     10            19
# 13935  2015-01-31           30                      9            21
# 14042  2015-02-14           10                      7             3
# 10708  2015-02-21           29                     10            19
#
#              venue             team1                team2 wloc
# 3731   Frost Arena  South Dakota St.     Eastern Illinois    H
# 22399  Frost Arena  South Dakota St.               Nevada    H
# 67     Frost Arena  North Dakota St.     South Dakota St.    A
# 202    Frost Arena         Milwaukee     South Dakota St.    A
# 3906   Frost Arena      Oral Roberts     South Dakota St.    A
# 11378  Frost Arena           Oakland     South Dakota St.    A
# 601    Frost Arena  South Dakota St.                 IPFW    H
# 19638  Frost Arena  South Dakota St.                IUPUI    H
# 19880  Frost Arena  South Dakota St.     Western Michigan    H
# 20080  Frost Arena  South Dakota St.              Oakland    H
# 11795  Frost Arena  South Dakota St.         Oral Roberts    H
# 15318  Frost Arena  South Dakota St.     North Dakota St.    H
# 12003  Frost Arena  South Dakota St.              Buffalo    H
# 4752   Frost Arena  South Dakota St.     Western Illinois    H
# 23413  Frost Arena  South Dakota St.        Tennessee St.    H
# 15574  Frost Arena  South Dakota St.  Cal St. Bakersfield    H
# 15636  Frost Arena  South Dakota St.              Oakland    H
# 12724  Frost Arena  South Dakota St.                 IPFW    H
# 2074   Frost Arena  South Dakota St.     North Dakota St.    H
# 5668   Frost Arena  South Dakota St.     Western Illinois    H
# 24081  Frost Arena           Montana     South Dakota St.    A
# 18463  Frost Arena  South Dakota St.               Howard    H
# 18489  Frost Arena  South Dakota St.               Lehigh    H
# 21054  Frost Arena  South Dakota St.              Belmont    H
# 9951   Frost Arena  South Dakota St.     Western Illinois    H
# 6428   Frost Arena    Nebraska Omaha     South Dakota St.    A
# 21531  Frost Arena  North Dakota St.     South Dakota St.    A
# 2604   Frost Arena  South Dakota St.                 IPFW    H
# 21821  Frost Arena  South Dakota St.               Denver    H
# 24573  Frost Arena  South Dakota St.         South Dakota    H
# 16524  Frost Arena  South Dakota St.         North Dakota    H
# 16574  Frost Arena  South Dakota St.                 UMKC    H
# 2983   Frost Arena  South Dakota St.                Idaho    H
# 10517  Frost Arena  South Dakota St.     Western Illinois    H
# 10582  Frost Arena  South Dakota St.                IUPUI    H
# 7523   Frost Arena  South Dakota St.         South Dakota    H
# 22103  Frost Arena  South Dakota St.                 IPFW    H
# 13935  Frost Arena  South Dakota St.               Denver    H
# 14042  Frost Arena  South Dakota St.     North Dakota St.    H
# 10708  Frost Arena  South Dakota St.         Oral Roberts    H

# %%
df = pd.read_sql("""SELECT * FROM kp_detailed""", conn)

# %%
df['winner'] = df.apply(lambda x: x.team1 if x.score1 > x.score2 else x.team2, axis=1)
df['correct'] = df.winner == df.predicted

# %%
df['month'] = df.dt.map(lambda x: x.month)

# %%
gb = df.groupby('month').mean()

# %%
gb.head()
# Out:
#           score1     score2  predicted_score  predicted_score2     team1_id  \
# month
# 1      73.373469  62.409621        71.489892         63.775122  1285.255423
# 2      73.138378  62.483283        71.151016         63.859382  1285.647256
# 3      72.785772  62.304662        70.834807         64.307476  1289.063103
# 11     75.720772  61.960110        72.935285         63.310842  1287.398260
# 12     74.533528  61.390282        72.713508         62.918562  1287.067444
#
#           team2_id        hteam        ateam   neutral   correct
# month
# 1      1283.172938  1284.330825  1284.097536  0.003246  0.709901
# 2      1282.525996  1284.099824  1284.073428  0.002240  0.724844
# 3      1287.752412  1287.392283  1289.423232  0.448151  0.719453
# 11     1283.661999  1288.062805  1282.997454  0.232548  0.781456
# 12     1281.372983  1286.988338  1281.452089  0.078523  0.781535

# %%
gb = df.groupby('neutral').mean()
