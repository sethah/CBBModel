# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psycopg2
# %matplotlib inline

# %%
conn = psycopg2.connect(database="cbb", user="seth", password="abc123",
                        host="localhost", port="5432")
cur = conn.cursor()

# %%
detailed = pd.read_sql("""SELECT * FROM reg_detailed""", conn)

# %%
detailed.head()
# Out:
#    season  daynum  wteam  wscore  lteam  lscore wloc  numot  wfgm  wfga  \
# 0    2003      10   1104      68   1328      62    N      0    27    58
# 1    2003      10   1272      70   1393      63    N      0    26    62
# 2    2003      11   1266      73   1437      61    N      0    24    58
# 3    2003      11   1296      56   1457      50    N      0    18    38
# 4    2003      11   1400      77   1208      71    N      0    30    61
#
#    wfgm3  wfga3  wftm  wfta  wor  wdr  wast  wto  wstl  wblk
# 0      3     14    11    18   14   24    13   23     7     1 ...
# 1      8     20    10    19   15   28    16   13     4     4 ...
# 2      8     18    17    29   17   26    15   10     5     2 ...
# 3      3      9    17    31    6   19    11   12    14     2 ...
# 4      6     14    11    13   17   22    12   14     4     4 ...
#
# [5 rows x 34 columns]

# %%
teams = pd.read_sql("""SELECT * FROM teams""", conn)

# %%
teams.head()
# Out:
#    team_id    team_name
# 0     1101  Abilene Chr
# 1     1102    Air Force
# 2     1103        Akron
# 3     1104      Alabama
# 4     1105  Alabama A&M
#
# [5 rows x 2 columns]

# %%
teams.shape
# Out:
# (364, 2)
